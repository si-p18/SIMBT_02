# %% [markdown]
# <a href="https://colab.research.google.com/github/si-p18/SIMBT_02/blob/main/PHOTO_TO_PENCIL_SKETCH_CONVERTER_jpynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Step1: Load the Dependencies

# %% [markdown]
# This section loads some required libraries used in this notebook:**numpy,pandas,cv2,skimage,PIL,matplotlib**
#
#
#
# *   Numpy is an array manipulation library,used for linear algebra, Fourier transform and random number capibilities
#
#
# *   Pandas is a library for data manpulation and data analysis
#
# *   CV2 is a library for computer vision tasks
#
#
# *   Skimage is a library which supports image processing applications on python
#
# *   Matplotlib is a library which generates figures and provides graphical user interface toolkit

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from PIL import Image
import matplotlib.pylab as plt

# %% [markdown]
# Step2: Read Image from Urls

# %% [markdown]
# In this step we will read image from urls, and display them using opencv

# %%
image = io.imread("/content/drive/MyDrive/Sid. jpeg.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=600x600 at 0x7FBB652027D0>

# %% [markdown]
# Step3: Operation performed on the image

# %%
grey_filter = cv.cvtColor(image,cv.COLOR_BGR2GRAY)
cv2_imshow(grey_filter)
# grey scale image generated from real image
# Out:
# <PIL.Image.Image image mode=L size=600x600 at 0x7FBB65EB3F40>

# %%
invert = cv.bitwise_not(grey_filter)
cv2_imshow(invert)
# grey scale image is inverted
# Out:
# <PIL.Image.Image image mode=L size=600x600 at 0x7FBB2191B820>

# %%
blur= cv.GaussianBlur(invert, (21,21),0)
cv2_imshow(blur)
# Out:
# <PIL.Image.Image image mode=L size=600x600 at 0x7FBB2191B790>

# %%
invertedblur= cv.bitwise_not(blur)
cv2_imshow(invertedblur)
# Out:
# <PIL.Image.Image image mode=L size=600x600 at 0x7FBB2191B580>

# %%
sketch_filter=cv.divide(grey_filter, invertedblur, scale=255.0)
cv2_imshow(sketch_filter)
cv.imwrite("sketch.jpg", sketch_filter)
# Out:
# <PIL.Image.Image image mode=L size=600x600 at 0x7FBB65202890>
# True
